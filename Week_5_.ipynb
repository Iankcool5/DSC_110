# %% [markdown]
# <a href="https://colab.research.google.com/github/Iankcool5/DSC_110/blob/main/Week_5_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
--This first line of code imports the library pandas

# %%
import pandas as pd

# %%
--This line of code imported a chart that imported information about id, gender, age, and other physical and other health traits

# %%
df = pd.read_csv('https://raw.githubusercontent.com/osoliman/DSC110/refs/heads/main/Datasets/nhanes_final.csv')

# %%
df
# Out:
#              id  gender   age  race_ethnicity  education   bmi  height_cm  \
# 0      130378.0     1.0  43.0             6.0        5.0  27.0      179.5
# 1      130379.0     1.0  66.0             3.0        5.0  33.5      174.2
# 2      130380.0     2.0  44.0             2.0        3.0  29.7      152.9
# 3      130381.0     2.0   5.0             7.0        NaN  23.8      120.1
# 4      130382.0     1.0   2.0             3.0        NaN   NaN        NaN
# ...         ...     ...   ...             ...        ...   ...        ...
# 11928  142306.0     1.0   9.0             2.0        NaN  15.4      128.0
# 11929  142307.0     2.0  49.0             4.0        5.0   NaN      143.8
# 11930  142308.0     1.0  50.0             2.0        4.0  26.4      173.3
# 11931  142309.0     1.0  40.0             2.0        4.0  25.5      179.1
# 11932  142310.0     2.0  80.0             3.0        3.0  27.6      161.7
#
#        systolic_bp  has_diabetes  hba1c  fasting_glucose
# ...

# %%
--This gives the first 5 rows of the chart

# %%
df.head()
# Out:
#          id  gender   age  race_ethnicity  education   bmi  height_cm  \
# 0  130378.0     1.0  43.0             6.0        5.0  27.0      179.5
# 1  130379.0     1.0  66.0             3.0        5.0  33.5      174.2
# 2  130380.0     2.0  44.0             2.0        3.0  29.7      152.9
# 3  130381.0     2.0   5.0             7.0        NaN  23.8      120.1
# 4  130382.0     1.0   2.0             3.0        NaN   NaN        NaN
#
#    systolic_bp  has_diabetes  hba1c  fasting_glucose
# 0        135.0           2.0    5.6            113.0
# 1        121.0           2.0    5.6             99.0
# 2        111.0           1.0    6.2            156.0
# 3          NaN           2.0    NaN              NaN
# 4          NaN           2.0    NaN              NaN

# %%
--This gives the last row of the chart

# %%
df.tail(1)
# Out:
#              id  gender   age  race_ethnicity  education   bmi  height_cm  \
# 11932  142310.0     2.0  80.0             3.0        3.0  27.6      161.7
#
#        systolic_bp  has_diabetes  hba1c  fasting_glucose
# 11932        128.0           2.0    5.3              NaN

# %%
--This is a line of code that gives the number of rows and columns

# %%
df.shape
# Out:
# (11933, 11)

# %%
--This line of code gives only the rows

# %%
df.shape[0]
# Out:
# 11933

# %%
--This line of code just prints in a sentence of how many rows and columns

# %%
print(f'The number of rows in our dataframe is {df.shape[0]} rows')
print(f'The number of columns in our dataframe is {df.shape[1]} columns')
# Out:
# The number of rows in our dataframe is 11933 rows
# The number of columns in our dataframe is 11 columns

# %%
--This gives the age for the first 5 rows due to use the command head

# %%
df['age'].head()
# Out:
# 0    43.0
# 1    66.0
# 2    44.0
# 3     5.0
# 4     2.0
# Name: age, dtype: float64

# %%
--The next few lines of code show how in python you do basic lines of math equations

# %%
1+1==2
# Out:
# True

# %%
1+1==3
# Out:
# False

# %%
int(1+1==2)
# Out:
# 1

# %%
int(1+1==3)
# Out:
# 0

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %% [markdown]
# **Data Cleaning**

# %%
--This line of code summarizes the data of each topic in the chart into one number.

# %%
df.isna().sum()
# Out:
# id                    0
# gender                0
# age                   0
# race_ethnicity        0
# education          4139
# bmi                3462
# height_cm          3434
# systolic_bp        4416
# has_diabetes        193
# hba1c              5218
# fasting_glucose    8261
# dtype: int64

# %%
--This finds the mean of all the data and multiples it by 100

# %%
df.isna().mean() * 100
# Out:
# id                  0.000000
# gender              0.000000
# age                 0.000000
# race_ethnicity      0.000000
# education          34.685326
# bmi                29.011984
# height_cm          28.777340
# systolic_bp        37.006620
# has_diabetes        1.617364
# hba1c              43.727478
# fasting_glucose    69.228191
# dtype: float64

# %%
--this is a command where if its a certian integer then they would have diabetes

# %%
df_clean = df.dropna(subset=['has_diabetes']).copy()

# %%
df_clean.isna().mean() * 100
# Out:
# id                  0.000000
# gender              0.000000
# age                 0.000000
# race_ethnicity      0.000000
# education          33.611584
# bmi                27.844974
# height_cm          27.606474
# systolic_bp        35.971039
# has_diabetes        0.000000
# hba1c              42.802385
# fasting_glucose    68.722317
# dtype: float64

# %%
--This line of code gives the current rows and columns availible

# %%
df_clean.shape
# Out:
# (11740, 11)

# %%
--This line of code finds the mean of all the bmi values on the list.

# %%
mean_bp = df_clean['systolic_bp'].mean()
print(mean_bp)
# Out:
# 119.28854596248503

# %%
df_clean['systolic_bp'] = df_clean['systolic_bp'].fillna(mean_bp)

# %%
df_clean['systolic_bp'].isna().sum()
# Out:
# np.int64(4223)

# %% [markdown]
# **Transform Variables**

# %%
--This line of code creates a system where depending on the bmi of the individual, it'll give thme the response of whether theey are any of the 4 options in the labels lines

# %%
df['bmi_category'] = pd.cut(df['bmi'],
                            bins=[0, 18.5, 25, 30, 100],
                            labels=['Underweight', 'Normal', 'Overweight', 'Obese'])

# %%
df['bmi_category'].head()
# Out:
# 0    Overweight
# 1         Obese
# 2    Overweight
# 3        Normal
# 4           NaN
# Name: bmi_category, dtype: category
# Categories (4, object): ['Underweight' < 'Normal' < 'Overweight' < 'Obese']

# %%
--This shows the number of people that fot each characteristic in the bmi category.

# %%
df['bmi_category'].value_counts()
# Out:
# bmi_category
# Obese          2666
# Normal         2400
# Overweight     2189
# Underweight    1216
# Name: count, dtype: int64

# %% [markdown]
# **Categorical Variable Transformation**

# %%
df['education'].head()
# Out:
# 0    5.0
# 1    5.0
# 2    3.0
# 3    NaN
# 4    NaN
# Name: education, dtype: float64

# %%
--This line of code creates a map of statements to give, based on what the user gives for their level of education
# Out:
#   File "/tmp/ipykernel_13535/1639892943.py", line 1
#     --This line of code creates a map of statements to give, based on what the user gives for their level of education
#            ^
# SyntaxError: invalid syntax

# %%
education_map = {
    1: 'Less than 9th grade',
    2: '9-11th grade',
    3: 'High school grad',
    4: 'Some college or AA degree',
    5: 'College graduate',
    9: 'Do not know',
    'nan': 'Missing'
}

# %%
--Putting 1 in the brackets prints out the sentence that is assigned to 1

# %%
education_map[1]
# Out:
# 'Less than 9th grade'

# %%
--This shows the number of indivaiduals in each category

# %%
df['education_label'] = df['education'].map(education_map)
df['education_label'].value_counts()
# Out:
# education_label
# College graduate             2625
# Some college or AA degree    2370
# High school grad             1749
# 9-11th grade                  666
# Less than 9th grade           373
# Do not know                    11
# Name: count, dtype: int64

# %%
df['education']
# Out:
# 0        5.0
# 1        5.0
# 2        3.0
# 3        NaN
# 4        NaN
#         ...
# 11928    NaN
# 11929    5.0
# 11930    4.0
# 11931    4.0
# 11932    3.0
# Name: education, Length: 11933, dtype: float64

# %%
df['education']
# Out:
# 0        5.0
# 1        5.0
# 2        3.0
# 3        NaN
# 4        NaN
#         ...
# 11928    NaN
# 11929    5.0
# 11930    4.0
# 11931    4.0
# 11932    3.0
# Name: education, Length: 11933, dtype: float64

# %% [markdown]
# **Data Summarization**

# %%
--The next few lines show that as long as you have a set of numbers you can fidn the mean, median, standard deviation, mode

# %%
avg_age = df['age'].mean()
print(f'The average age in our date set is {round(avg_age,0)}')
# Out:
# The average age in our date set is 38.0

# %%
std_age = df['age'].std()
print(f'The standard deviation for age in our data is {round(std_age,0)}')
# Out:
# The standard deviation for age in our data is 26.0

# %%
df['age'].median()
# Out:
# 37.0

# %%
df['age'].mean()
# Out:
# np.float64(38.317858040727394)

# %%
df['age'].mode()
# Out:
# 0    80.0
# Name: age, dtype: float64

# %%
--Saying describe shows everything in a chart format for age

# %%
df['age'].describe()
# Out:
# count    1.193300e+04
# mean     3.831786e+01
# std      2.560199e+01
# min      5.397605e-79
# 25%      1.300000e+01
# 50%      3.700000e+01
# 75%      6.200000e+01
# max      8.000000e+01
# Name: age, dtype: float64

# %%
--The line df['gender'].value_counts() is used to count the occurrences of each unique value in the 'gender' column of my DataFrame df

# %%
df['gender'].value_counts()
# Out:
# gender
# 2.0    6358
# 1.0    5575
# Name: count, dtype: int64

# %%
--This is the chart that shows the number of people in each category based on their BMI.

# %%
pd.crosstab(df['has_diabetes'], df['bmi_category'])
# Out:
# bmi_category  Underweight  Normal  Overweight  Obese
# has_diabetes
# 1.0                     4     109         233    504
# 2.0                  1211    2251        1886   2042
# 3.0                     0      39          70    120
# 9.0                     1       1           0      0

# %%
pd.crosstab(df['has_diabetes'], df['bmi_category'], normalize='index') * 100
# Out:
# bmi_category  Underweight     Normal  Overweight      Obese
# has_diabetes
# 1.0              0.470588  12.823529   27.411765  59.294118
# 2.0             16.387009  30.460081   25.520974  27.631935
# 3.0              0.000000  17.030568   30.567686  52.401747
# 9.0             50.000000  50.000000    0.000000   0.000000

# %%
df.groupby('has_diabetes')['bmi'].mean()
# Out:
# has_diabetes
# 1.0    32.981412
# 2.0    26.439797
# 3.0    32.068559
# 9.0    19.250000
# Name: bmi, dtype: float64

# %%
--In this line it creates a boxplot to show the data based on whats inputed.

# %%
df.boxplot(column='bmi', by='gender')
# Out:
# <Axes: title={'center': 'bmi'}, xlabel='gender'>

# %%
-- What I did differently for this code was add more detailed comments to the code to truly show what it does.I also corrected some of the code that was wrond so it would run properly
